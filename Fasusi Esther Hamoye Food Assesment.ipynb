# %%
import numpy as np
import pandas as pd

# %%
path= open(r"C:\Users\PC\Documents\Hamoye Classwork\CSV File\Hamoye Food Balance Sheets_CSV.csv")
data= pd.read_csv(path)
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
path= open(r"C:\Users\PC\Documents\Hamoye Classwork\CSV File\Hamoye Food Balance Sheets_CSV.csv")
data= pd.read_csv(path)
data.count()
# Out:
# Area Code       60943
# Area            60943
# Item Code       60943
# Item            60943
# Element Code    60943
# Element         60943
# Unit            60943
# Y2014           59354
# Y2015           59395
# Y2016           59408
# Y2017           59437
# Y2018           59507
# dtype: int64

# %%
import seaborn as sns

# %%
#import plotting library
import matplotlib.pyplot as plt
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
item_code=pd.DataFrame({'unit':['BBL','GAL','GRAMSU','KGU','MCF','MMBTU','MWDTH','MWHTH','TON'],
                       'count':[7998,84,464,110,11354,180,95,100,8958]})
sns.barplot(data=item_code, x='unit', y='count')
plt.xlabel('Item Code')
# Out:
# Text(0.5, 0, 'Item Code')

# %%
data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
data.mean()
# Out:
# Area Code        134.265576
# Item Code       2687.176706
# Element Code    3814.856456
# Y2014            134.196282
# Y2015            135.235966
# Y2016            136.555222
# Y2017            140.917765
# Y2018            143.758381
# dtype: float64

# %%
data.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %%
data.dropna()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data.sum()
# Out:
# Area Code                                                 8182547
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                               163764610
# Item            PopulationPopulationGrand TotalGrand TotalGran...
# Element Code                                            232488797
# Element         Total Population - Both sexesDomestic supply q...
# Unit            1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                                  7965086.13
# Y2015                                                  8032340.23
# Y2016                                                  8112472.65
# Y2017                                                  8375729.19
# Y2018                                                  8554629.96
# dtype: object

# %%
import numpy as np
import pandas as pd

# %%
path= open(r"C:\Users\PC\Documents\Hamoye Classwork\CSV File\Hamoye Food Balance Sheets_CSV.csv")
data= pd.read_csv(path)
data.sum()
# Out:
# Area Code                                                 8182547
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                               163764610
# Item            PopulationPopulationGrand TotalGrand TotalGran...
# Element Code                                            232488797
# Element         Total Population - Both sexesDomestic supply q...
# Unit            1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                                  7965086.13
# Y2015                                                  8032340.23
# Y2016                                                  8112472.65
# Y2017                                                  8375729.19
# Y2018                                                  8554629.96
# dtype: object

# %%
Food=pd.Series(['Area Code','Item code','Element','Y2014','Y2015','Y2016','Y2017','Y2018'])
print(Food)
# Out:
# 0    Area Code
# 1    Item code
# 2      Element
# 3        Y2014
# 4        Y2015
# 5        Y2016
# 6        Y2017
# 7        Y2018
# dtype: object

# %%
food_list=np.array(['Area Code','Item code','Element','Y2014','Y2015','Y2016','Y2017','Y2018'])
numpy_food=pd.Series(food_list)
print(numpy_food)
# Out:
# 0    Area Code
# 1    Item code
# 2      Element
# 3        Y2014
# 4        Y2015
# 5        Y2016
# 6        Y2017
# 7        Y2018
# dtype: object

# %%
print(pd.DataFrame())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#importing pandas as pd
import pandas as pd
#creating the dataframe
df=pd.read_csv(r"C:\Users\PC\Documents\Hamoye Classwork\CSV File\Hamoye Food Balance Sheets_CSV.csv") 
#print the dataframe
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
gk=df.groupby('country')
gk.mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-4e4e7639b14e> in <module>
# ----> 1 gk=df.groupby('country')
#       2 gk.mean()
#
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# C:\Users\pc\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
# ...

# %%
gk=df.groupby('Element')
gk.sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
gk=df.groupby('Y2016')
gk.first()
# Out:
#            Area Code          Area  Item Code                      Item  \
# Y2016
# -3225.0          143       Morocco       2905  Cereals - Excluding Beer
# -2051.0          143       Morocco       2511        Wheat and products
# -1499.0          202  South Africa       2905  Cereals - Excluding Beer
# -1324.0          202  South Africa       2514        Maize and products
# -1088.0          143       Morocco       2513       Barley and products
# ...              ...           ...        ...                       ...
#  94447.0          59         Egypt       2501                Population
#  103603.0        238      Ethiopia       2501                Population
#  116483.0        159       Nigeria       2907             Starchy Roots
#  119330.0        159       Nigeria       2907             Starchy Roots
#  185960.0        159       Nigeria       2501                Population
#
#            Element Code                        Element          Unit  \
# Y2016
# ...

# %%
gk=df.groupby('Y2015')
gk.first()
# Out:
#            Area Code          Area  Item Code                      Item  \
# Y2015
# -3161.0          202  South Africa       2905  Cereals - Excluding Beer
# -2152.0          202  South Africa       2514        Maize and products
# -1284.0          276         Sudan       2905  Cereals - Excluding Beer
# -907.0           251        Zambia       2905  Cereals - Excluding Beer
# -887.0           276         Sudan       2518      Sorghum and products
# ...              ...           ...        ...                       ...
#  92443.0          59         Egypt       2501                Population
#  100835.0        238      Ethiopia       2501                Population
#  110798.0        159       Nigeria       2907             Starchy Roots
#  111663.0        159       Nigeria       2907             Starchy Roots
#  181137.0        159       Nigeria       2501                Population
#
#            Element Code                        Element          Unit  \
# Y2015
# ...

# %%
gk=df.groupby('Y2017')
gk.first()
# Out:
#            Area Code                         Area  Item Code  \
# Y2017
# -1582.0           59                        Egypt       2908
# -1200.0          144                   Mozambique       2532
# -1159.0          144                   Mozambique       2907
# -865.0           215  United Republic of Tanzania       2913
# -860.0           215  United Republic of Tanzania       2556
# ...              ...                          ...        ...
#  96443.0          59                        Egypt       2501
#  106400.0        238                     Ethiopia       2501
#  112625.0        159                      Nigeria       2907
#  117702.0        159                      Nigeria       2907
#  190873.0        159                      Nigeria       2501
#
#                               Item  Element Code  \
# Y2017
# -1582.0                Sugar Crops          5072
# -1200.0       Cassava and products          5072
# -1159.0              Starchy Roots          5072
# ...

# %%
gk=df.groupby('Y2018')
gk.first()
# Out:
#            Area Code        Area  Item Code                      Item  \
# Y2018
# -3396.0           59       Egypt       2905  Cereals - Excluding Beer
# -2450.0           59       Egypt       2514        Maize and products
# -2156.0           59       Egypt       2908               Sugar Crops
# -1445.0          144  Mozambique       2532      Cassava and products
# -1442.0          144  Mozambique       2907             Starchy Roots
# ...              ...         ...        ...                       ...
#  98424.0          59       Egypt       2501                Population
#  109224.0        238    Ethiopia       2501                Population
#  117038.0        159     Nigeria       2907             Starchy Roots
#  118172.0        159     Nigeria       2907             Starchy Roots
#  195875.0        159     Nigeria       2501                Population
#
#            Element Code                        Element          Unit  \
# Y2018
# ...

# %%
gk=df.groupby('Unit')
gk.first()
# Out:
#                  Area Code     Area  Item Code                      Item  \
# Unit
# 1000 persons             4  Algeria       2501                Population
# 1000 tonnes              4  Algeria       2501                Population
# g/capita/day             4  Algeria       2901               Grand Total
# kcal/capita/day          4  Algeria       2901               Grand Total
# kg                       4  Algeria       2905  Cereals - Excluding Beer
#
#                  Element Code                                 Element  \
# Unit
# 1000 persons              511           Total Population - Both sexes
# 1000 tonnes              5301                Domestic supply quantity
# g/capita/day              674  Protein supply quantity (g/capita/day)
# kcal/capita/day           664           Food supply (kcal/capita/day)
# kg                        645     Food supply quantity (kg/capita/yr)
#
#                     Y2014     Y2015     Y2016     Y2017     Y2018
# Unit
# ...

# %%
gk=df.groupby('Element Code')
gk.sum()
# Out:
#               Area Code  Item Code       Y2014       Y2015       Y2016  \
# Element Code
# 511                6020     112545  1031585.00  1058081.00  1085107.00
# 645              658446   13185401    49650.63    49345.13    48985.28
# 664              674057   13511060   454257.00   453383.00   451810.00
# 674              675050   13535000    11836.46    11833.95    11779.69
# 684              675050   13535000    10225.56    10235.74    10102.77
# 5072             571566   11329527    58749.83    34910.99    33140.12
# 5123             274353    5424803   153223.00   155439.00   157787.00
# 5131             271940    5350416   282923.00   287929.00   280631.00
# 5142             663295   13285035  1212332.49  1232361.10  1247022.17
# 5154             235554    4729749    78718.13    66254.41    69563.68
# 5170             623271   12421089    30149.00    30045.00    37224.00
# 5171              50308    1486528      416.00      349.00       89.00
# ...

# %%
gk=df.groupby('Area Code')
gk.first()
# Out:
#                                   Area  Item Code             Item  \
# Area Code
# 4                              Algeria       2501       Population
# 7                               Angola       2501       Population
# 20                            Botswana       2501       Population
# 32                            Cameroon       2501       Population
# 35                          Cabo Verde       2501       Population
# 37            Central African Republic       2501       Population
# 39                                Chad       2501       Population
# 45                             Comoros       2781   Fish, Body Oil
# 46                               Congo       2501       Population
# 53                               Benin       2501       Population
# 59                               Egypt       2501       Population
# 62                        Ethiopia PDR       2782  Fish, Liver Oil
# 72                            Djibouti       2501       Population
# ...

# %%
gk=df.groupby('Area Code')
gk.last()
# Out:
#                                   Area  Item Code             Item  \
# Area Code
# 4                              Algeria       2899    Miscellaneous
# 7                               Angola       2899    Miscellaneous
# 20                            Botswana       2899    Miscellaneous
# 32                            Cameroon       2899    Miscellaneous
# 35                          Cabo Verde       2899    Miscellaneous
# 37            Central African Republic       2899    Miscellaneous
# 39                                Chad       2899    Miscellaneous
# 45                             Comoros       2767  Molluscs, Other
# 46                               Congo       2899    Miscellaneous
# 53                               Benin       2899    Miscellaneous
# 59                               Egypt       2899    Miscellaneous
# 62                        Ethiopia PDR       2767  Molluscs, Other
# 72                            Djibouti       2899    Miscellaneous
# ...

# %%
gk=df.groupby('Element Code')
gk.last()
# Out:
#               Area Code                   Area  Item Code  \
# Element Code
# 511                 181               Zimbabwe       2501
# 645                 181               Zimbabwe       2899
# 664                 181               Zimbabwe       2899
# 674                 181               Zimbabwe       2899
# 684                 181               Zimbabwe       2899
# 5072                181               Zimbabwe       2899
# 5123                181               Zimbabwe       2848
# 5131                181               Zimbabwe       2848
# 5142                181               Zimbabwe       2899
# 5154                181               Zimbabwe       2775
# 5170                181               Zimbabwe       2899
# 5171                193  Sao Tome and Principe       2899
# 5301                181               Zimbabwe       2899
# 5511                181               Zimbabwe       2765
# 5521                181               Zimbabwe       2763
# ...

# %%
gk=df.groupby('Item Code')
gk.last()
# Out:
#            Area Code      Area                     Item  Element Code  \
# Item Code
# 2501             181  Zimbabwe               Population          5301
# 2511             181  Zimbabwe       Wheat and products           684
# 2513             181  Zimbabwe      Barley and products           684
# 2514             181  Zimbabwe       Maize and products           684
# 2515             181  Zimbabwe         Rye and products           684
# ...              ...       ...                      ...           ...
# 2946             181  Zimbabwe              Animal fats           684
# 2948             181  Zimbabwe  Milk - Excluding Butter           684
# 2949             181  Zimbabwe                     Eggs           684
# 2960             181  Zimbabwe            Fish, Seafood           684
# 2961             181  Zimbabwe  Aquatic Products, Other           684
#
#                                       Element          Unit  Y2014  Y2015  \
# Item Code
# ...

# %%
gk=df.groupby('Y2014')
gk.sum()
# Out:
#            Area Code  Item Code  Element Code     Y2015     Y2016     Y2017  \
# Y2014
# -1796.0          159       2657          5072     -73.0     -12.0       0.0
# -1631.0          159       2924          5072       6.0     -77.0    -689.0
# -849.0           266       5444         10340   -1118.0   -1119.0   -1200.0
# -838.0           184       2907          5072    -827.0    -679.0    -538.0
# -685.0           143       2905          5072    3418.0   -3225.0     689.0
# ...              ...        ...           ...       ...       ...       ...
#  90425.0          59       2501           511   92443.0   94447.0   96443.0
#  98094.0         238       2501           511  100835.0  103603.0  106400.0
#  108756.0        159       2907          5301  110798.0  116483.0  112625.0
#  109593.0        159       2907          5511  111663.0  119330.0  117702.0
#  176405.0        159       2501           511  181137.0  185960.0  190873.0
#
#               Y2018
# Y2014
# ...

# %%
path= open(r"C:\Users\PC\Documents\Hamoye Classwork\CSV File\Hamoye Food Balance Sheets_CSV.csv")
data= pd.read_csv(path)
df.
data.sum()
